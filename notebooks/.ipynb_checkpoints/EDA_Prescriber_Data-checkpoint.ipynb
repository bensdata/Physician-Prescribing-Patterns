# %%
import pandas as pd

# %%
#prescriber_df = pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__2017_Part_D_Prescriber.csv')
#prescriber_df = prescriber_df.drop(['description_flag','bene_count_ge65_suppress_flag','ge65_suppress_flag',''])
prescriber_df = prescriber_df.rename(columns={'nppes_provider_last_org_name': 'last_name', 'nppes_provider_city': 'city',
                                              'nppes_provider_state':'state',''})

# %%
prescriber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25209130 entries, 0 to 25209129
# Data columns (total 21 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   npi                            int64
#  1   last_name                      object
#  2   nppes_provider_first_name      object
#  3   nppes_provider_city            object
#  4   nppes_provider_state           object
#  5   specialty_description          object
#  6   description_flag               object
#  7   drug_name                      object
#  8   generic_name                   object
#  9   bene_count                     float64
#  10  total_claim_count              int64
#  11  total_30_day_fill_count        float64
#  12  total_day_supply               int64
#  13  total_drug_cost                float64
#  14  bene_count_ge65                float64
#  15  bene_count_ge65_suppress_flag  object
#  16  total_claim_count_ge65         float64
# ...

# %%
prescriber_df.nunique()
# Out:
# npi                               918009
# last_name                         224648
# nppes_provider_first_name          68802
# nppes_provider_city                12135
# nppes_provider_state                  61
# specialty_description                188
# description_flag                       2
# drug_name                           2821
# generic_name                        1606
# bene_count                          1108
# total_claim_count                   3421
# total_30_day_fill_count            25779
# total_day_supply                   61562
# total_drug_cost                  2468337
# bene_count_ge65                      995
# bene_count_ge65_suppress_flag          2
# total_claim_count_ge65              2901
# ge65_suppress_flag                     2
# total_30_day_fill_count_ge65       23318
# total_day_supply_ge65              55651
# total_drug_cost_ge65             1730011
# dtype: int64

# %%
prescriber_df.generic_name.value_counts().head(60)
# Out:
# LEVOTHYROXINE SODIUM              356968
# METFORMIN HCL                     341252
# ALBUTEROL SULFATE                 313164
# ATORVASTATIN CALCIUM              302657
# GABAPENTIN                        302441
# LISINOPRIL                        291299
# HYDROCODONE/ACETAMINOPHEN         289372
# AMLODIPINE BESYLATE               288571
# POTASSIUM CHLORIDE                276124
# OMEPRAZOLE                        271877
# FUROSEMIDE                        259852
# PREDNISONE                        254763
# METOPROLOL SUCCINATE              242839
# METOPROLOL TARTRATE               235337
# LOSARTAN POTASSIUM                234221
# FLUTICASONE PROPIONATE            232210
# SIMVASTATIN                       230389
# TRAMADOL HCL                      228958
# PANTOPRAZOLE SODIUM               228156
# HYDROCHLOROTHIAZIDE               227662
# INSULIN GLARGINE,HUM.REC.ANLOG    217824
# DILTIAZEM HCL                     206791
# SERTRALINE HCL                    201840
# ...

# %%
prescriber_df['specialty_description'].value_counts().head(60)
# Out:
# Family Practice                                                   7087620
# Internal Medicine                                                 6563601
# Nurse Practitioner                                                3133372
# Physician Assistant                                               1430495
# Cardiology                                                         834793
# Psychiatry                                                         659407
# General Practice                                                   481873
# Neurology                                                          405232
# Emergency Medicine                                                 298943
# Nephrology                                                         294921
# Ophthalmology                                                      280055
# Endocrinology                                                      253592
# Pulmonary Disease                                                  233434
# ...

# %%
prescriber_df.head()
# Out:
#           npi    last_name nppes_provider_first_name nppes_provider_city  \
# 0  1245201227     GRUENDEL                      JOHN              CARMEL
# 1  1649591223       RAMOSO                    WESLEY              EUGENE
# 2  1548398597        GLENN                     TERRI                ACME
# 3  1780674101     MITCHELL                  KIMBERLY               CABOT
# 4  1861502288  SEYEDKAZEMI                   MAHSHID         LOS ANGELES
#
#   nppes_provider_state specialty_description description_flag      drug_name  \
# 0                   NY            Cardiology                S      TOPROL XL
# 1                   OR       Family Practice                S       NOVOFINE
# 2                   MI    Nurse Practitioner                S   VALACYCLOVIR
# 3                   AR             Optometry                S        LUMIGAN
# 4                   CA            Pharmacist                T  CLONIDINE HCL
#
# ...
