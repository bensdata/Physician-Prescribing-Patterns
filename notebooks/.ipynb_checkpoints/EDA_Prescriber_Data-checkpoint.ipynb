# %%
import pandas as pd

# %%
prescriber_df = pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__2017_Part_D_Prescriber.csv')
#prescriber_df = prescriber_df.drop([''])

# %%
prescriber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25209130 entries, 0 to 25209129
# Data columns (total 21 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   npi                            int64
#  1   nppes_provider_last_org_name   object
#  2   nppes_provider_first_name      object
#  3   nppes_provider_city            object
#  4   nppes_provider_state           object
#  5   specialty_description          object
#  6   description_flag               object
#  7   drug_name                      object
#  8   generic_name                   object
#  9   bene_count                     float64
#  10  total_claim_count              int64
#  11  total_30_day_fill_count        float64
#  12  total_day_supply               int64
#  13  total_drug_cost                float64
#  14  bene_count_ge65                float64
#  15  bene_count_ge65_suppress_flag  object
#  16  total_claim_count_ge65         float64
# ...

# %%
prescriber_df[prescriber_df['specialty_description']=='Nurse Practitioner']
# Out:
#                  npi nppes_provider_last_org_name nppes_provider_first_name  \
# 2         1548398597                        GLENN                     TERRI
# 6         1851761894                     BANKSTON                   HAKIMAH
# 8         1003858150                       LUCKEY                     CAROL
# 9         1184627192                        WHITE                     KATHY
# 13        1477804466                     ROBINSON                  LAKEESHA
# ...              ...                          ...                       ...
# 25209096  1841742046                        SAISI                   NATALIE
# 25209098  1407122179                        LOWRY                     TRACY
# 25209102  1497750301                       HUNTER                     LAURA
# 25209110  1124418678                   VILLAGOMEZ                    SILVIA
# 25209117  1992053367                       ARAUJO                    ROXANA
#
# ...

# %%
prescriber_df['npi'].nunique()
# Out:
# 918009

# %%
prescriber_df['nppes_provider_last_org_name'].nunique()
# Out:
# 224648

# %%
prescriber_df['nppes_provider_first_name'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-92f7cc09288e> in <module>
# ----> 1 prescriber_df['nppes_provider_first_name'].nunique()
#
# NameError: name 'prescriber_df' is not defined

# %%
prescriber_df.description_flag.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e0e9612e5fbd> in <module>
# ----> 1 prescriber_df.description_flag.value_counts()
#
# NameError: name 'prescriber_df' is not defined
