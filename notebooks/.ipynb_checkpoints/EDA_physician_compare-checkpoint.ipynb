# %%
import pandas as pd
import collections

# %%
df = pd.read_csv('../data/Physician_Compare_National_Downloadable_File.csv')
# Out:
# C:\Users\ben\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (15,25,29,31,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df.drop(['PAC ID', 'Professional Enrollment ID','Middle Name','Suffix','Gender','Secondary specialty 2',
         'Secondary specialty 3','Secondary specialty 4','All secondary specialties','Line 1 Street Address',
         'Line 2 Street Address','Marker of address line 2 suppression','Phone Number'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2183992 entries, 0 to 2183991
# Data columns (total 25 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   NPI                                       int64
#  1   Last Name                                 object
#  2   First Name                                object
#  3   Credential                                object
#  4   Medical school name                       object
#  5   Graduation year                           float64
#  6   Primary specialty                         object
#  7   Secondary specialty 1                     object
#  8   Organization legal name                   object
#  9   Group Practice PAC ID                     float64
#  10  Number of Group Practice members          float64
#  11  City                                      object
#  12  State                                     object
# ...

# %%
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2183992 entries, 0 to 2183991
# Data columns (total 25 columns):
#  #   Column                                    Non-Null Count    Dtype
# ---  ------                                    --------------    -----
#  0   NPI                                       2183992 non-null  int64
#  1   Last Name                                 2183947 non-null  object
#  2   First Name                                2183971 non-null  object
#  3   Credential                                648578 non-null   object
#  4   Medical school name                       2183986 non-null  object
#  5   Graduation year                           2179074 non-null  float64
#  6   Primary specialty                         2183992 non-null  object
#  7   Secondary specialty 1                     308331 non-null   object
#  8   Organization legal name                   2011537 non-null  object
# ...

# %%
print(df['Hospital affiliation CCN 1'].isnull().value_counts())
print(df['Hospital affiliation CCN 1'].nunique())
print(df['Hospital affiliation LBN 1'].isnull().value_counts())
print(df['Hospital affiliation CCN 2'].isnull().value_counts())
print(df['Hospital affiliation CCN 3'].isnull().value_counts())
print(df['Hospital affiliation CCN 4'].isnull().value_counts())
print(df['Hospital affiliation CCN 5'].isnull().value_counts())

# %%
df.to_csv('../data/phys_compare_clean.csv')

# %%
print(df['Hospital affiliation CCN 1'].nunique())
# Out:
# 4644

# %%
df['Primary specialty'].value_counts()

# %%
df[df['Primary specialty']=='NURSE PRACTITIONER']

# %%
df['NPI'].nunique()
# Out:
# 1138209

# %%
df['Medical school name'].value_counts()
#pd.set_option('display.max_rows', 500)
# Out:
# OTHER                                                                                            1130696
# WAYNE STATE UNIVERSITY SCHOOL OF MEDICINE                                                          18198
# INDIANA UNIVERSITY SCHOOL OF MEDICINE                                                              17799
# UNIVERSITY OF MINNESOTA MEDICAL SCHOOL                                                             15993
# UNIVERSITY OF MICHIGAN MEDICAL SCHOOL                                                              15299
# OHIO STATE UNIVERSITY COLLEGE OF MEDICINE                                                          13711
# PHILADELPHIA COLLEGE OF OSTEOPATHIC MEDICINE                                                       13342
# UNIVERSITY OF ILLINOIS AT CHICAGO HEALTH SCIENCE CENTER                                            13331
# TEMPLE UNIVERSITY SCHOOL OF MEDICINE                                                               12627
# ...
