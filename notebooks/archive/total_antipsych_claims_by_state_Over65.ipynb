# %%
import pandas as pd

# %%
claims_by_state = pd.read_csv('../../data/antipsych_drugs_usa_over65.csv',
                                             usecols=['npi','state','bene_count_ge65','total_claim_count_ge65'])

# %%
claims_by_state.shape
# Out:
# (380112, 4)

# %%
claims_by_state.head()
# Out:
#           npi state  bene_count_ge65  total_claim_count_ge65
# 0  1952306417    PA              NaN                    43.0
# 1  1427075894    TN              NaN                    25.0
# 2  1427075894    TN              NaN                     NaN
# 3  1427075894    TN              NaN                     NaN
# 4  1427075894    TN              NaN                    17.0

# %%
total_antipsych_claims_by_state = claims_by_state.groupby(['state'])['total_claim_count_ge65'].sum().to_frame()

# %%
total_antipsych_claims_by_state.to_csv('../../data/csv_for_visualization/total_antipsych_claims_by_state_Over65.csv')

# %%
total_antipsych_claims_by_state.head(70)
# Out:
#        total_claim_count_ge65
# state
# AE                       12.0
# AK                     6086.0
# AL                   110339.0
# AR                    53859.0
# AZ                    74364.0
# CA                   530730.0
# CO                    55226.0
# CT                    95249.0
# DC                     8298.0
# DE                    16082.0
# FL                   418082.0
# GA                   240734.0
# GU                       62.0
# HI                    13512.0
# IA                    72091.0
# ID                    21067.0
# IL                   233108.0
# IN                   124973.0
# KS                    60773.0
# KY                   110373.0
# LA                   113164.0
# MA                   191585.0
# MD                    89921.0
# ME                    25027.0
# MI                   203965.0
# MN                   122789.0
# MO                   148509.0
# MS                    70182.0
# MT                    15834.0
# NC                   180546.0
# ...
